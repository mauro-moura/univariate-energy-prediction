# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd './drive/MyDrive/Davi_Code'
# Out:
# /content/drive/MyDrive/Davi_Code

# %%
# !python main.py
# Out:
# Iniciando Treinamento
# Iniciando Teste
# Tempo de Execução 12.6 segundos
# {'MSE': 1499.3400725148374, 'MAE': 18.727747212840523, 'MAPE': 0.11152555713358091, 'R2': 0.9748061494905108, 'Tempo': 12.599648475646973}

# %%
# UCI:    {'MSE': 0.20918280740635462, 'MAE': 0.254848748373854, 'MAPE': 0.26189707210355456, 'R2': 0.77020198210094, 'Tempo': 858.9754581451416}
# Labic:  161,949 segundos
